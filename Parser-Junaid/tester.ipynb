# %% [markdown]
# # Creating Instance of Parser

# %%
from LR1Parser import LR1Parser, green_text, normal_text_start

parser = LR1Parser()
parser.define_grammar()
parser.augment_grammar()
parser.compute_first_sets()
parser.build_canonical_collection()
parser.build_parsing_tables()


print(f"{green_text}Parser is ready!{normal_text_start}")
# Out:
# Parser is ready!

# %% [markdown]
# ## Test-1: Simple Declaration and Initialization

# %%
from LR1Parser import Token
# Test case 1: simple declaration and initialization
"""
Test Program:
integer main () {
    integer a equals to 10;
    return a;
}
"""
tokens = [
    Token('TYPE', 'integer'),
    Token('KEYWORD', 'main'),
    Token('LPAREN', '('),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'a'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '10'),
    Token('SEMI', 'semicolon'),
    Token('KEYWORD', 'return'),
    Token('IDENTIFIER', 'a'),
    Token('SEMI', 'semicolon'),
    Token('RBRACE', '}'),
    Token('$', '$')
]

ast, tac = parser.test_program(
    tokens, 
    "simple declaration and initialization", 
    "integer a equals to 10;",
    create_visualization=True
)


print(f"============================================================")
# Out:
# === TEST: simple declaration and initialization ===
# Testing: integer a equals to 10;
#
# Parsing log saved to 'test-simple-declaration-and-initialization-log.txt'
#
# === SEMANTIC ANALYSIS ===
# ✓ No semantic errors found!
#
# Parsing: SUCCESS
# Semantic Analysis: SUCCESS
#
# Parse Tree Structure:
# Program
#   MainFunction
#     Type
#       TYPE: integer
#     KEYWORD: main
#     LPAREN: (
#     RPAREN: )
#     LBRACE: {
#     StatementList
#       StatementList
#         Statement
#           Declaration
#             Type
#               TYPE: integer
#             IDENTIFIER: a
#             ASSIGN_OP: equals to
#             Expression
#               LogicalExpr
#                 RelationalExpr
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           NUMBER: 10
#           SEMI: semicolon
#       Statement
#         ReturnStatement
#           KEYWORD: return
#           Expression
#             LogicalExpr
#               RelationalExpr
#                 ArithmeticExpr
#                   Term
#                     PowerExpr
#                       Factor
#                         IDENTIFIER: a
#           SEMI: semicolon
#     RBRACE: }
#
# === INTERMEDIATE REPRESENTATION ===
#
# Abstract Syntax Tree:
# program
#   function: main
#     block
#       block
#         declaration: a
#           literal: 10
#       return
#         variable: a
#
# === Three-Address Code ===
#
# function main:
#     1: t0 = 10
#     2: declare integer a
#     3: a = t0
#     4: return a
# 🎨 Creating Parse Tree Visualization in: ast-simple-declaration-and-initialization.png
#
# Parse Tree visualization saved to: ast-simple-declaration-and-initialization.png
# 🎨 Creating IR AST visualization: ir-simple-declaration-and-initialization.png
#
# IR AST visualization saved to: ir-simple-declaration-and-initialization.png
#
# ============================================================
# ============================================================

# %% [markdown]
# ## Test-2: Type-Mismatch (semantic error)

# %%
# Test case 2: type mismatch, a boolean variable assigned an integer value
"""
Test Program:
integer main () {
    boolean a equals to 10;
}
"""
# Test with a program that has a type mismatch
tokens_type_mismatch = [
    Token('TYPE', 'integer'),
    Token('KEYWORD', 'main'),
    Token('LPAREN', '('),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    Token('TYPE', 'boolean'),
    Token('IDENTIFIER', 'a'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '10'),
    Token('SEMI', 'semicolon'),
    Token('RBRACE', '}'),
    Token('$', '$')
]

ast, tac = parser.test_program(
    tokens_type_mismatch, 
    "type mismatch in assignment", 
    "boolean a equals to 10;",
    create_visualization=True
)


print(f"============================================================")
# Out:
# === TEST: type mismatch in assignment ===
# Testing: boolean a equals to 10;
#
# Parsing log saved to 'test-type-mismatch-in-assignment-log.txt'
#
# === SEMANTIC ANALYSIS ===
# Found 1 semantic errors:
# - Type mismatch: cannot assign integer to boolean variable 'a'
#
# Parsing: SUCCESS
# Semantic Analysis: FAILED
#
# Parse Tree Structure:
# Program
#   MainFunction
#     Type
#       TYPE: integer
#     KEYWORD: main
#     LPAREN: (
#     RPAREN: )
#     LBRACE: {
#     StatementList
#       Statement
#         Declaration
#           Type
#             TYPE: boolean
#           IDENTIFIER: a
#           ASSIGN_OP: equals to
#           Expression
#             LogicalExpr
#               RelationalExpr
#                 ArithmeticExpr
#                   Term
#                     PowerExpr
#                       Factor
#                         NUMBER: 10
#         SEMI: semicolon
#     RBRACE: }
# 🎨 Creating Parse Tree Visualization in: ast-type-mismatch-in-assignment.png
#
# Parse Tree visualization saved to: ast-type-mismatch-in-assignment.png
#
# ============================================================
# ============================================================

# %% [markdown]
# ## Test-3: Missing semi-colon (parsing/syntax error)

# %%
# Test case 3: missing semicolon
"""
Test Program:
integer main () {
    integer a equals to 10
}
"""

tokens_missing_semicolon = [
    Token('TYPE', 'integer'),
    Token('KEYWORD', 'main'),
    Token('LPAREN', '('),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    Token('TYPE', 'boolean'),
    Token('IDENTIFIER', 'a'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '10'),
    #Token('SEMI', 'semicolon'),
    Token('RBRACE', '}'),
    Token('$', '$')
]

ast, tac = parser.test_program(
    tokens_missing_semicolon, 
    "missing semicolon in assignment", 
    "integer a equals to 10",
    create_visualization=True
)


print(f"============================================================")
# Out:
# === TEST: missing semicolon in assignment ===
# Testing: integer a equals to 10
#
# Parsing log saved to 'test-missing-semicolon-in-assignment-log.txt'
#
# Parsing: FAILED
# Error details:
#  - Possible syntax error: Missing semicolon before closing brace
#
# Context around error:
# ...
#   1: KEYWORD(main)
#   2: LPAREN(()
#   3: RPAREN())
#   4: LBRACE({)
#   5: TYPE(boolean)
# → 6: IDENTIFIER(a)
#   7: ASSIGN_OP(equals to)
#   8: NUMBER(10)
#   9: RBRACE(})
#   10: $($)
#
#
# ============================================================
# ============================================================

# %% [markdown]
# ## Test-4: Using Uninitialized variables (semantic error)

# %%
# Test case 4: missing semicolon
"""
Test Program:
integer main () {
    boolean a;          // declared but not initialized
    integer b;          // declared but not initialized
    if(a is greater than b) {  // using uninitialized variables
        integer c equals to 10;
    }
}
"""

tokens_uninitialized = [
    # integer main () {
    Token('TYPE', 'integer'),
    Token('KEYWORD', 'main'),
    Token('LPAREN', '('),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    
    # boolean a;
    Token('TYPE', 'boolean'),
    Token('IDENTIFIER', 'a'),
    Token('SEMI', 'semicolon'),
    
    # integer b;
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'b'),
    Token('SEMI', 'semicolon'),
    
    # if(a is greater than b) {
    Token('KEYWORD', 'if'),
    Token('LPAREN', '('),
    Token('IDENTIFIER', 'a'),
    Token('RELATIONAL_OP', 'is greater than'),
    Token('IDENTIFIER', 'b'),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    
    # integer c equals to 10;
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'c'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '10'),
    Token('SEMI', 'semicolon'),
    
    # }
    Token('RBRACE', '}'),
    # }
    Token('RBRACE', '}'),
    Token('$', '$')
]



ast, tac = parser.test_program(
    tokens_uninitialized, 
    "uninitialized variables in condition", 
    "boolean a; integer b; if(a is greater than b)",
    create_visualization=True
)


print(f"============================================================")
# Out:
# === TEST: uninitialized variables in condition ===
# Testing: boolean a; integer b; if(a is greater than b)
#
# Parsing log saved to 'test-uninitialized-variables-in-condition-log.txt'
#
# === SEMANTIC ANALYSIS ===
# Found 4 semantic errors:
# - Variable 'a' used before initialization
# - Variable 'b' used before initialization
# - Variable 'a' used before initialization
# - Variable 'b' used before initialization
#
# Parsing: SUCCESS
# Semantic Analysis: FAILED
#
# Parse Tree Structure:
# Program
#   MainFunction
#     Type
#       TYPE: integer
#     KEYWORD: main
#     LPAREN: (
#     RPAREN: )
#     LBRACE: {
#     StatementList
#       StatementList
#         StatementList
#           Statement
#             Declaration
#               Type
#                 TYPE: boolean
#               IDENTIFIER: a
#             SEMI: semicolon
#         Statement
#           Declaration
#             Type
#               TYPE: integer
#             IDENTIFIER: b
#           SEMI: semicolon
#       Statement
#         IfStatement
#           KEYWORD: if
#           LPAREN: (
#           Condition
#             Expression
#               LogicalExpr
#                 RelationalOperation: is greater than
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           IDENTIFIER: a
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           IDENTIFIER: b
#           RPAREN: )
#           LBRACE: {
#           StatementList
#             Statement
#               Declaration
#                 Type
#                   TYPE: integer
#                 IDENTIFIER: c
#                 ASSIGN_OP: equals to
#                 Expression
#                   LogicalExpr
#                     RelationalExpr
#                       ArithmeticExpr
#                         Term
#                           PowerExpr
#                             Factor
#                               NUMBER: 10
#               SEMI: semicolon
#           RBRACE: }
#     RBRACE: }
# 🎨 Creating Parse Tree Visualization in: ast-uninitialized-variables-in-condition.png
#
# Parse Tree visualization saved to: ast-uninitialized-variables-in-condition.png
#
# ============================================================
# ============================================================

# %% [markdown]
# ## Test-5: Complete Valid Program

# %%
"""
integer main () {
    integer x equals to 5 semicolon
    integer y equals to 10 semicolon
    boolean result equals to x is less than y semicolon
    if (result) {
        integer sum equals to x add y semicolon
        }
}
"""

tokens_valid = [
    # integer main () {
    Token('TYPE', 'integer'),
    Token('KEYWORD', 'main'),
    Token('LPAREN', '('),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    
    # integer x equals to 5;
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'x'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '5'),
    Token('SEMI', 'semicolon'),
    
    # integer y equals to 10;
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'y'),
    Token('ASSIGN_OP', 'equals to'),
    Token('NUMBER', '10'),
    Token('SEMI', 'semicolon'),
    
    # boolean result equals to x is less than y;
    Token('TYPE', 'boolean'),
    Token('IDENTIFIER', 'result'),
    Token('ASSIGN_OP', 'equals to'),
    Token('IDENTIFIER', 'x'),
    Token('RELATIONAL_OP', 'is less than'),
    Token('IDENTIFIER', 'y'),
    Token('SEMI', 'semicolon'),
    
    # if (result) {
    Token('KEYWORD', 'if'),
    Token('LPAREN', '('),
    Token('IDENTIFIER', 'result'),
    Token('RPAREN', ')'),
    Token('LBRACE', '{'),
    
    # integer sum equals to x add y;
    Token('TYPE', 'integer'),
    Token('IDENTIFIER', 'sum'),
    Token('ASSIGN_OP', 'equals to'),
    Token('IDENTIFIER', 'x'),
    Token('ARITHMETIC_OP', 'add'),
    Token('IDENTIFIER', 'y'),
    Token('SEMI', 'semicolon'),
    
    # }
    Token('RBRACE', '}'),
    # }
    Token('RBRACE', '}'),
    Token('$', '$')
]




ast, tac = parser.test_program(
    tokens_valid, 
    "complete valid program", 
    "integer x equals to 5; integer y equals to 10; boolean result equals to x is less than y; if (result) { integer sum equals to x add y; }",
    create_visualization=True
)


print(f"============================================================")
# Out:
# === TEST: complete valid program ===
# Testing: integer x equals to 5; integer y equals to 10; boolean result equals to x is less than y; if (result) { integer sum equals to x add y; }
#
# Parsing log saved to 'test-complete-valid-program-log.txt'
#
# === SEMANTIC ANALYSIS ===
# ✓ No semantic errors found!
#
# Parsing: SUCCESS
# Semantic Analysis: SUCCESS
#
# Parse Tree Structure:
# Program
#   MainFunction
#     Type
#       TYPE: integer
#     KEYWORD: main
#     LPAREN: (
#     RPAREN: )
#     LBRACE: {
#     StatementList
#       StatementList
#         StatementList
#           StatementList
#             Statement
#               Declaration
#                 Type
#                   TYPE: integer
#                 IDENTIFIER: x
#                 ASSIGN_OP: equals to
#                 Expression
#                   LogicalExpr
#                     RelationalExpr
#                       ArithmeticExpr
#                         Term
#                           PowerExpr
#                             Factor
#                               NUMBER: 5
#               SEMI: semicolon
#           Statement
#             Declaration
#               Type
#                 TYPE: integer
#               IDENTIFIER: y
#               ASSIGN_OP: equals to
#               Expression
#                 LogicalExpr
#                   RelationalExpr
#                     ArithmeticExpr
#                       Term
#                         PowerExpr
#                           Factor
#                             NUMBER: 10
#             SEMI: semicolon
#         Statement
#           Declaration
#             Type
#               TYPE: boolean
#             IDENTIFIER: result
#             ASSIGN_OP: equals to
#             Expression
#               LogicalExpr
#                 RelationalOperation: is less than
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           IDENTIFIER: x
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           IDENTIFIER: y
#           SEMI: semicolon
#       Statement
#         IfStatement
#           KEYWORD: if
#           LPAREN: (
#           Condition
#             Expression
#               LogicalExpr
#                 RelationalExpr
#                   ArithmeticExpr
#                     Term
#                       PowerExpr
#                         Factor
#                           IDENTIFIER: result
#           RPAREN: )
#           LBRACE: {
#           StatementList
#             Statement
#               Declaration
#                 Type
#                   TYPE: integer
#                 IDENTIFIER: sum
#                 ASSIGN_OP: equals to
#                 Expression
#                   LogicalExpr
#                     RelationalExpr
#                       BinaryOperation: add
#                         ArithmeticExpr
#                           Term
#                             PowerExpr
#                               Factor
#                                 IDENTIFIER: x
#                         Term
#                           PowerExpr
#                             Factor
#                               IDENTIFIER: y
#               SEMI: semicolon
#           RBRACE: }
#     RBRACE: }
#
# === INTERMEDIATE REPRESENTATION ===
#
# Abstract Syntax Tree:
# program
#   function: main
#     block
#       block
#         block
#           block
#             declaration: x
#               literal: 5
#           declaration: y
#             literal: 10
#         declaration: result
#           binary_op: is less than
#             variable: x
#             variable: y
#       if
#         variable: result
#         block
#           declaration: sum
#             binary_op: add
#               variable: x
#               variable: y
#
# === Three-Address Code ===
#
# function main:
#     1: t0 = 5
#     2: declare integer x
#     3: x = t0
#     4: t1 = 10
#     5: declare integer y
#     6: y = t1
#     7: t2 = x is less than y
#     8: declare boolean result
#     9: result = t2
#     10: if result goto L0
#     11: goto L1
#
# L0:
#     13: t3 = x add y
#     14: declare integer sum
#     15: sum = t3
#     16: goto L1
#
# L1:
# 🎨 Creating Parse Tree Visualization in: ast-complete-valid-program.png
#
# Parse Tree visualization saved to: ast-complete-valid-program.png
# 🎨 Creating IR AST visualization: ir-complete-valid-program.png
#
# IR AST visualization saved to: ir-complete-valid-program.png
#
# ============================================================
# ============================================================

# %%
tac
# Out:
# ['function main:',
#  't0 = 5',
#  'declare integer x',
#  'x = t0',
#  't1 = 10',
#  'declare integer y',
#  'y = t1',
#  't2 = x is less than y',
#  'declare boolean result',
#  'result = t2',
#  'if result goto L0',
#  'goto L1',
#  'L0:',
#  't3 = x add y',
#  'declare integer sum',
#  'sum = t3',
#  'goto L1',
#  'L1:']

# %%
tac
